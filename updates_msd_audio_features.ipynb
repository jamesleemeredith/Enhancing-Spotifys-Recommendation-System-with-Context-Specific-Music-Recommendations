# %%
# Imports Required for Accessing the MSD data
import os
import sys
import glob
import tables

# Imports Required for Querying the Spotify API and Creating the Spotify Audio Features Dataset
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotifyusercredentials
import pandas as pd

# Spotify API Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=spotifyusercredentials.client_ID, client_secret=spotifyusercredentials.client_SECRET)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Establishes path to the Million Song Dataset (or subset)
msd_path='./data/MillionSongSubset'

# Establishes path to the Million Song Dataset code
msd_code_path='./code/MSongsDB'
assert os.path .isdir(msd_code_path),'wrong path' # sanity check
# we add some paths to python so we can import MSD code
sys.path.append( os.path.join(msd_code_path,'PythonSrc') )

# Imports the MSD Python modules we need
import hdf5_getters as GETTERS

# %%
# we define this very useful function to iterate through all the files in the dataset
def apply_to_all_files(basedir,func=lambda x: x,ext='.h5'):
    """
    From a base directory, go through all subdirectories,
    find all files with the given extension, apply the
    given function 'func' to all of them.
    If no 'func' is passed, we do nothing except counting.
    INPUT
       basedir  - base directory of the dataset
       func     - function to apply to all filenames
       ext      - extension, .h5 by default
    RETURN
       number of files
    """
    cnt = 0
    # iterate over all files in all subdirectories
    for root, dirs, files in os.walk(basedir):
        files = glob.glob(os.path.join(root,'*'+ext))
        # count files
        cnt += len(files)
        # apply function to all files
        for f in files :
            func(f)       
    return cnt

# %%
# Defines a function that queries the Spotify API for the audio features of a file
def get_spotify_audio_features(filename, dataframe):
    # Opens the file
    file = GETTERS.open_h5_file_read(filename)
    # Creates a variable track_id that contains the track id in a file
    msd_track_id = GETTERS.get_track_id(file).decode('utf-8')
    # Creates a variable song_title that contains the song title in a file
    song_title = GETTERS.get_title(file).decode('utf-8')
    # Creates a variable release that contains the release in a file
    album_name = GETTERS.get_release(file).decode('utf-8')
    # Creates a variable artist_name that contains the artist name in a file
    artist_name = GETTERS.get_artist_name(file).decode('utf-8')
    # Build the search query
    api_query = f'track:{song_title} album:{album_name} artist:{artist_name}'
    # Queries Spotify API for song data using the song title, album title, and artist
    results = sp.search(q=api_query, type='track', limit=1)
    # Extracts the spotify track id from the results
    spotify_track_id = results['tracks']['items'][0]['id']
    # Queries Spotify API for audio features using the track id
    audio_features = sp.audio_features([spotify_track_id])
    # Appends the audio features to the global dataframe
    audio_features_df = pd.DataFrame(audio_features, index=[msd_track_id])
    dataframe = pd.concat([dataframe, audio_features_df], ignore_index=False)
    # Closes the file
    file.close()
    # Return the updated dataframe
    return dataframe

# %%
import os
import glob
import pandas as pd

# Defines a function that queries the Spotify API for the audio features of a file
def get_spotify_audio_features(filename, dataframe):
    # Opens the file
    file = GETTERS.open_h5_file_read(filename)
    # Creates a variable track_id that contains the track id in a file
    msd_track_id = GETTERS.get_track_id(file).decode('utf-8')
    # Creates a variable song_title that contains the song title in a file
    song_title = GETTERS.get_title(file).decode('utf-8')
    # Creates a variable release that contains the release in a file
    album_name = GETTERS.get_release(file).decode('utf-8')
    # Creates a variable artist_name that contains the artist name in a file
    artist_name = GETTERS.get_artist_name(file).decode('utf-8')
    # Build the search query
    api_query = f'track:{song_title} album:{album_name} artist:{artist_name}'
    # Queries Spotify API for song data using the song title, album title, and artist
    results = sp.search(q=api_query, type='track', limit=1)
    # Check if any tracks were found
    # if len(results['tracks']['items']) > 0:
        # Extracts the Spotify track id from the results
        spotify_track_id = results['tracks']['items'][0]['id']
        # Queries Spotify API for audio features using the track id
        audio_features = sp.audio_features([spotify_track_id])
        # Appends the audio features to the global dataframe
        audio_features_df = pd.DataFrame(audio_features, index=[msd_track_id])
        dataframe = pd.concat([dataframe, audio_features_df], ignore_index=False)
    # else:
    #     print(f"No results found for file: {filename}")
    # Closes the file
    file.close()
    # Return the updated dataframe
    return dataframe


# Combines the two functions
def get_all_audio_features(basedir, ext='.h5'):
    """
    From a base directory, go through all subdirectories,
    find all files with the given extension, and get the audio features
    for each .h5 file from the Spotify API.
    Returns a dataframe of all the audio features.
    """
    dataframe = pd.DataFrame()  # Create an empty dataframe to store the audio features
    # iterate over all files in all subdirectories
    for root, dirs, files in os.walk(basedir):
        files = glob.glob(os.path.join(root, '*' + ext))
        # apply function to all files
        for f in files:
            dataframe = get_spotify_audio_features(f, dataframe)
    return dataframe

# %%
get_all_audio_features(msd_path, ext='.h5')
# Out:
# No results found for file: ./data/MillionSongSubset\A\A\A\TRAAADZ128F9348C2E.h5
# No results found for file: ./data/MillionSongSubset\A\A\A\TRAAAVG12903CFA543.h5
# No results found for file: ./data/MillionSongSubset\A\A\B\TRAABCL128F4286650.h5
# No results found for file: ./data/MillionSongSubset\A\A\B\TRAABDL12903CAABBA.h5
# No results found for file: ./data/MillionSongSubset\A\A\B\TRAABJL12903CDCF1A.h5
# No results found for file: ./data/MillionSongSubset\A\A\B\TRAABVM128F92CA9DC.h5
# No results found for file: ./data/MillionSongSubset\A\A\B\TRAABXG128F9318EBD.h5
# No results found for file: ./data/MillionSongSubset\A\A\B\TRAABYN12903CFD305.h5
# No results found for file: ./data/MillionSongSubset\A\A\C\TRAACHN128F1489601.h5
# No results found for file: ./data/MillionSongSubset\A\A\C\TRAACOW128F933E35F.h5
# No results found for file: ./data/MillionSongSubset\A\A\C\TRAACSL128F93462F4.h5
# No results found for file: ./data/MillionSongSubset\A\A\C\TRAACVS128E078BE39.h5
# No results found for file: ./data/MillionSongSubset\A\A\D\TRAADDS128F425C68B.h5
# No results found for file: ./data/MillionSongSubset\A\A\D\TRAADEV128F9348C0A.h5
# No results found for file: ./data/MillionSongSubset\A\A\D\TRAADLN128F14832E9.h5
# No results found for file: ./data/MillionSongSubset\A\A\D\TRAADOF12903CAA1C1.h5
# No results found for file: ./data/MillionSongSubset\A\A\D\TRAADVH128EF34DE7A.h5
# No results found for file: ./data/MillionSongSubset\A\A\D\TRAADYI128E078FB38.h5
# No results found for file: ./data/MillionSongSubset\A\A\E\TRAAEAM128F934B199.h5
# No results found for file: ./data/MillionSongSubset\A\A\E\TRAAEEH128E0795DFE.h5
# No results found for file: ./data/MillionSongSubset\A\A\E\TRAAENP128F147BF32.h5
# No results found for file: ./data/MillionSongSubset\A\A\E\TRAAEXM128F92D47C8.h5
# No results found for file: ./data/MillionSongSubset\A\A\F\TRAAFJW128F428A424.h5
# No results found for file: ./data/MillionSongSubset\A\A\F\TRAAFUJ128F933F42B.h5
# No results found for file: ./data/MillionSongSubset\A\A\F\TRAAFYL128E07856A7.h5
# No results found for file: ./data/MillionSongSubset\A\A\G\TRAAGCZ128F93210FD.h5
# No results found for file: ./data/MillionSongSubset\A\A\G\TRAAGGE128F9325E2C.h5
# No results found for file: ./data/MillionSongSubset\A\A\G\TRAAGJV128F1464090.h5
# No results found for file: ./data/MillionSongSubset\A\A\G\TRAAGKS128F9314884.h5
# No results found for file: ./data/MillionSongSubset\A\A\G\TRAAGNL128F4299BF1.h5
# No results found for file: ./data/MillionSongSubset\A\A\G\TRAAGPF12903CE027E.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHDH128F93094B6.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHEQ128F93057B4.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHER128F92E3FE9.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHMO128F92DE7C9.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHVY128F92E25D6.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHXN128F9326097.h5
# No results found for file: ./data/MillionSongSubset\A\A\H\TRAAHYV128F932A425.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIAN12903CFF16D.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIAX128F930531B.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIFG12903CB0BCB.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIIE128F4288BB1.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIII128F427D5D8.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAILM128F93480BB.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAINT128F933BBE0.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIRG128F93265E8.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIXN128F428027A.h5
# No results found for file: ./data/MillionSongSubset\A\A\I\TRAAIXU128F4241E5C.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJBU12903CE2831.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJEK128F422F55A.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJJA12903CC518A.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJMH128E0785407.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJNM12903CF4750.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJSX128F4275A1D.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJVJ128F42570AD.h5
# No results found for file: ./data/MillionSongSubset\A\A\J\TRAAJXQ128F92E65BF.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKAS128F4246013.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKAV128F931BE25.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKDG128F42A0ECB.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKNS12903CC5198.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKQS128F4224DE1.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKVD12903CE8474.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKVZ12903D074BB.h5
# No results found for file: ./data/MillionSongSubset\A\A\K\TRAAKXN128F92E71B1.h5
# No results found for file: ./data/MillionSongSubset\A\A\L\TRAALCM128F4264370.h5
# No results found for file: ./data/MillionSongSubset\A\A\L\TRAALNG12903D014E9.h5
# No results found for file: ./data/MillionSongSubset\A\A\L\TRAALUX12903CFD50B.h5
# No results found for file: ./data/MillionSongSubset\A\A\L\TRAALZN128F932D457.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMFG128F92FDEA2.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMFT128F93128AD.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMII128F933B583.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMKI128F428537A.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMKL128F9347D8A.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMKP12903CC74F4.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMYQ128F148B753.h5
# No results found for file: ./data/MillionSongSubset\A\A\M\TRAAMZB12903CAB002.h5
# No results found for file: ./data/MillionSongSubset\A\A\N\TRAANKK128F42531BC.h5
# No results found for file: ./data/MillionSongSubset\A\A\N\TRAANMF12903CEAFEF.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_all_audio_features(msd_path, ext='.h5')
#
# Cell In[1], line 52, in get_all_audio_features(basedir, ext)
#      50     # apply function to all files
#      51     for f in files:
# ---> 52         dataframe = get_spotify_audio_features(f, dataframe)
#      53 return dataframe
#
# Cell In[1], line 20, in get_spotify_audio_features(filename, dataframe)
#      18 api_query = f'track:{song_title} album:{album_name} artist:{artist_name}'
#      19 # Queries Spotify API for song data using the song title, album title, and artist
# ---> 20 results = sp.search(q=api_query, type='track', limit=1)
#      21 # Check if any tracks were found
#      22 if len(results['tracks']['items']) > 0:
#      23     # Extracts the Spotify track id from the results
#
# File c:\Users\James\anaconda3\lib\site-packages\spotipy\client.py:587, in Spotify.search(self, q, limit, offset, type, market)
#     572 def search(self, q, limit=10, offset=0, type="track", market=None):
#     573     """ searches for an item
#     574
#     575         Parameters:
#    (...)
#     585                        from_token.
#     586     """
# --> 587     return self._get(
#     588         "search", q=q, limit=limit, offset=offset, type=type, market=market
#     589     )
#
# File c:\Users\James\anaconda3\lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\James\anaconda3\lib\site-packages\spotipy\client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File c:\Users\James\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\James\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\James\anaconda3\lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File c:\Users\James\anaconda3\lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\James\anaconda3\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\James\anaconda3\lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\James\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\James\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\James\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\James\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\James\anaconda3\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\James\anaconda3\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
